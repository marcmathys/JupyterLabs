# %%
import pandas as pd
# %pwd
# Out:
# '/Users/marcmathys/Downloads/JupyterLabs/Data'

# %%
# %cd /Users/marcmathys/Downloads/JupyterLabs/Data
# %ls
# %matplotlib widget
# Out:
# /Users/marcmathys/Downloads/JupyterLab/Data
# data_10.xls* data_18.xls* data_26.xls* data_34.xls* data_42.xls* data_50.xls*
# data_11.xls* data_19.xls* data_27.xls* data_35.xls* data_43.xls* data_51.xls*
# data_12.xls* data_20.xls* data_28.xls* data_36.xls* data_44.xls* data_52.xls*
# data_13.xls* data_21.xls* data_29.xls* data_37.xls* data_45.xls* data_53.xls*
# data_14.xls* data_22.xls* data_30.xls* data_38.xls* data_46.xls*
# data_15.xls* data_23.xls* data_31.xls* data_39.xls* data_47.xls*
# data_16.xls* data_24.xls* data_32.xls* data_40.xls* data_48.xls*
# data_17.xls* data_25.xls* data_33.xls* data_41.xls* data_49.xls*

# %%
df = pd.read_csv('data_18.xls', sep='\t',  lineterminator='\n', header=[5], index_col=0)

# %%
df = df.drop(df.columns[[4, 5, 6, 7]], axis=1)
df.columns=['Lab1','Lab2','n/a','ekg']
df.head()
# Out:
#                 Lab1       Lab2       n/a        ekg
# Time
# 225,000000  0,002824  -0,017893  1,411577  -0,100760
# 225,001000  0,002824  -0,017893  1,411577  -0,100760
# 225,002000  0,002824  -0,017893  1,411577  -0,100760
# 225,003000  0,002824  -0,017893  1,411577  -0,080044
# 225,004000  0,002824  -0,017893  1,411577  -0,100760

# %%
import plotly.express as px

fig = px.line(df, y=['ekg', 'Lab1', 'Lab2'])
# fig.add_trace(px.scatter(df, y=df['v0']))
fig.show()

# %%
dddff
